# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
df = pd.read_csv ('glass.csv')
X = df.iloc[:,0:9]
y = df["Type"]

# %%
# Load the data from “glass.csv” and make a bar plot of different types of glasses. 
Y = y.value_counts()
Y.plot.bar()
# Out:
# <Axes: xlabel='Type'>

# %%
from sklearn.tree import DecisionTreeClassifier
x_train, x_test, y_train, y_test = train_test_split(X,y,random_state =5)
# Create Decision Tree classifer object
dtc = DecisionTreeClassifier()
# Train Decision Tree Classifer
dtc = dtc.fit(x_train,y_train)
#Predict the response for test dataset
y_pred = dtc.predict(x_test)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7777777777777778

# %%
# Repeating with random state = 42
df = pd.read_csv ('glass.csv')
X = df.iloc[:,0:9]
y = df["Type"]
x_train, x_test, y_train, y_test = train_test_split(X,y,random_state =42)
# Create Decision Tree classifer object
dtc = DecisionTreeClassifier()
# Train Decision Tree Classifer
dtc = dtc.fit(x_train,y_train)
#Predict the response for test dataset
y_pred = dtc.predict(x_test)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7222222222222222

# %%
# Repeating with random state = 0
df = pd.read_csv ('glass.csv')
X = df.iloc[:,0:9]
y = df["Type"]
x_train, x_test, y_train, y_test = train_test_split(X,y,random_state =0)
# Create Decision Tree classifer object
dtc = DecisionTreeClassifier()
# Train Decision Tree Classifer
dtc = dtc.fit(x_train,y_train)
#Predict the response for test dataset
y_pred = dtc.predict(x_test)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6296296296296297

# %%
df = pd.read_csv ('glass.csv')
X = df.iloc[:,0:9]
y = df["Type"]
x_train, x_test, y_train, y_test = train_test_split(X,y,random_state =5)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
y_pred = knn.predict(x_test)
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.6666666666666666

# %%
# random_state =42

df = pd.read_csv ('glass.csv')
X = df.iloc[:,0:9]
y = df["Type"]
x_train, x_test, y_train, y_test = train_test_split(X,y,random_state =42)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
y_pred = knn.predict(x_test)
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.7037037037037037

# %%
# trying KFold
from sklearn.model_selection import cross_val_score
df = pd.read_csv ('glass.csv')
X = df.iloc[:,0:9]
y = df["Type"]
scores=[]
from sklearn.model_selection import KFold
kf = KFold(n_splits=3,random_state=42,shuffle=True)
for train_index,test_index in kf.split(X):
    X_train, X_test, y_train, y_test = train_test_split(X,y)
    knn.fit(X_train, y_train)
    scores.append(knn.score(X_test, y_test))
knn.fit(X_train,y_train)
scores.append(knn.score(X_test,y_test))
print(np.mean(scores))
cross_val_score(knn, X, y, cv=10)
# Out:
# 0.6435185185185185
# C:\Users\SiyaPransh\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# array([0.63636364, 0.5       , 0.72727273, 0.59090909, 0.71428571,
#        0.80952381, 0.76190476, 0.38095238, 0.71428571, 0.66666667])

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
df = pd.read_csv ('glass.csv')
X = df.iloc[:,0:9]
y = df["Type"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7441860465116279
